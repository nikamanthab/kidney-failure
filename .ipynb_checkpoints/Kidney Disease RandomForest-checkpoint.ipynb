# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 30)
# %matplotlib inline

# %%
df = pd.read_csv('./kidney_disease.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# 0   no            ckd
# 1   no            ckd
# 2  yes            ckd
# 3  yes            ckd
# 4   no            ckd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
# id                400 non-null int64
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# rbc               248 non-null object
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# sod               313 non-null float64
# pot               312 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# wc                295 non-null object
# rc                270 non-null object
# htn               398 non-null object
# dm                398 non-null object
# cad               398 non-null object
# appet             399 non-null object
# pe                399 non-null object
# ane               399 non-null object
# classification    400 non-null object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.3+ KB

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.corr())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 3 to 399
# Data columns (total 26 columns):
# id                158 non-null int64
# age               158 non-null float64
# bp                158 non-null float64
# sg                158 non-null float64
# al                158 non-null float64
# su                158 non-null float64
# rbc               158 non-null object
# pc                158 non-null object
# pcc               158 non-null object
# ba                158 non-null object
# bgr               158 non-null float64
# bu                158 non-null float64
# sc                158 non-null float64
# sod               158 non-null float64
# pot               158 non-null float64
# hemo              158 non-null float64
# pcv               158 non-null object
# wc                158 non-null object
# rc                158 non-null object
# htn               158 non-null object
# dm                158 non-null object
# cad               158 non-null object
# appet             158 non-null object
# pe                158 non-null object
# ane               158 non-null object
# classification    158 non-null object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 33.3+ KB

# %%
df.head()
# Out:
#     id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3    3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9    9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11  11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14  14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20  20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
#
#             ba    bgr     bu   sc    sod  pot  hemo pcv     wc   rc  htn   dm  \
# 3   notpresent  117.0   56.0  3.8  111.0  2.5  11.2  32   6700  3.9  yes   no
# 9   notpresent   70.0  107.0  7.2  114.0  3.7   9.5  29  12100  3.7  yes  yes
# 11  notpresent  380.0   60.0  2.7  131.0  4.2  10.8  32   4500  3.8  yes  yes
# 14     present  157.0   90.0  4.1  130.0  6.4   5.6  16  11000  2.6  yes  yes
# 20  notpresent  173.0  148.0  3.9  135.0  5.2   7.7  24   9200  3.2  yes  yes
#
#     cad appet   pe  ane classification
# 3    no  poor  yes  yes            ckd
# 9    no  poor   no  yes            ckd
# 11   no  poor  yes   no            ckd
# 14  yes  poor  yes   no            ckd
# 20  yes  poor  yes  yes            ckd

# %%
df['rbc'].replace('normal',1,inplace=True)
df['rbc'].replace('abnormal',0,inplace=True)

# %%
df['pc'].replace('abnormal',0,inplace=True)
df['pc'].replace('normal',1,inplace=True)
# Out:
#       id   age     bp     sg   al   su  rbc        pc         pcc          ba  \
# 3      3  48.0   70.0  1.005  4.0  0.0    1  abnormal     present  notpresent
# 9      9  53.0   90.0  1.020  2.0  0.0    0  abnormal     present  notpresent
# 11    11  63.0   70.0  1.010  3.0  0.0    0  abnormal     present  notpresent
# 14    14  68.0   80.0  1.010  3.0  2.0    1  abnormal     present     present
# 20    20  61.0   80.0  1.015  2.0  0.0    0  abnormal  notpresent  notpresent
# 22    22  48.0   80.0  1.025  4.0  0.0    1  abnormal  notpresent  notpresent
# 27    27  69.0   70.0  1.010  3.0  4.0    1  abnormal  notpresent  notpresent
# 48    48  73.0   70.0  1.005  0.0  0.0    1    normal  notpresent  notpresent
# 58    58  73.0   80.0  1.020  2.0  0.0    0  abnormal  notpresent  notpresent
# 71    71  46.0   60.0  1.010  1.0  0.0    1    normal  notpresent  notpresent
# 74    74  56.0   90.0  1.015  2.0  0.0    0  abnormal  notpresent  notpresent
# 76    76  48.0   80.0  1.005  4.0  0.0    0  abnormal  notpresent     present
# 84    84  59.0   70.0  1.010  3.0  0.0    1  abnormal  notpresent  notpresent
# 90    90  63.0  100.0  1.010  2.0  2.0    1    normal  notpresent     present
# 91    91  56.0   70.0  1.015  4.0  1.0    0    normal  notpresent  notpresent
# 92    92  71.0   70.0  1.010  3.0  0.0    1  abnormal     present     present
# 93    93  73.0  100.0  1.010  3.0  2.0    0  abnormal     present  notpresent
# 127  127  71.0   60.0  1.015  4.0  0.0    1    normal  notpresent  notpresent
# 128  128  52.0   90.0  1.015  4.0  3.0    1  abnormal  notpresent  notpresent
# 130  130  50.0   90.0  1.010  2.0  0.0    1  abnormal     present     present
# 133  133  70.0  100.0  1.015  4.0  0.0    1    normal  notpresent  notpresent
# 144  144  60.0   90.0  1.010  2.0  0.0    0    normal  notpresent  notpresent
# 147  147  60.0   60.0  1.010  3.0  1.0    1  abnormal     present  notpresent
# 153  153  55.0   90.0  1.010  2.0  1.0    0  abnormal  notpresent  notpresent
# 157  157  62.0   70.0  1.025  3.0  0.0    1  abnormal  notpresent  notpresent
# 159  159  59.0   80.0  1.010  1.0  0.0    0    normal  notpresent  notpresent
# 171  171  83.0   70.0  1.020  3.0  0.0    1    normal  notpresent  notpresent
# 176  176  21.0   90.0  1.010  4.0  0.0    1  abnormal     present     present
# 181  181  45.0   70.0  1.025  2.0  0.0    1  abnormal     present  notpresent
# 189  189  64.0   60.0  1.010  4.0  1.0    0  abnormal  notpresent     present
# ..   ...   ...    ...    ...  ...  ...  ...       ...         ...         ...
# 368  368  30.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 369  369  75.0   70.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 370  370  69.0   70.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 371  371  28.0   60.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 372  372  72.0   60.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 373  373  61.0   70.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 374  374  79.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 375  375  70.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 376  376  58.0   70.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 377  377  64.0   70.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 379  379  62.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 380  380  59.0   60.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 382  382  48.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 383  383  80.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 384  384  57.0   60.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 385  385  63.0   70.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 386  386  46.0   70.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 387  387  15.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 388  388  51.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 389  389  41.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 390  390  52.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 391  391  36.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 392  392  57.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 393  393  43.0   60.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 394  394  50.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 395  395  55.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 396  396  42.0   70.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 397  397  12.0   80.0  1.020  0.0  0.0    1    normal  notpresent  notpresent
# 398  398  17.0   60.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
# 399  399  58.0   80.0  1.025  0.0  0.0    1    normal  notpresent  notpresent
#
#        bgr     bu    sc    sod   pot  hemo pcv      wc   rc  htn   dm  cad  \
# 3    117.0   56.0   3.8  111.0   2.5  11.2  32    6700  3.9  yes   no   no
# 9     70.0  107.0   7.2  114.0   3.7   9.5  29   12100  3.7  yes  yes   no
# 11   380.0   60.0   2.7  131.0   4.2  10.8  32    4500  3.8  yes  yes   no
# 14   157.0   90.0   4.1  130.0   6.4   5.6  16   11000  2.6  yes  yes  yes
# 20   173.0  148.0   3.9  135.0   5.2   7.7  24    9200  3.2  yes  yes  yes
# 22    95.0  163.0   7.7  136.0   3.8   9.8  32    6900  3.4  yes   no   no
# 27   264.0   87.0   2.7  130.0   4.0  12.5  37    9600  4.1  yes  yes  yes
# 48    70.0   32.0   0.9  125.0   4.0  10.0  29   18900  3.5  yes  yes   no
# 58   253.0  142.0   4.6  138.0   5.8  10.5  33    7200  4.3  yes  yes  yes
# 71   163.0   92.0   3.3  141.0   4.0   9.8  28   14600  3.2  yes  yes   no
# 74   129.0  107.0   6.7  131.0   4.8   9.1  29    6400  3.4  yes   no   no
# 76   133.0  139.0   8.5  132.0   5.5  10.3  36  \t6200    4   no  yes   no
# 84    76.0  186.0  15.0  135.0   7.6   7.1  22    3800  2.1  yes   no   no
# 90   280.0   35.0   3.2  143.0   3.5  13.0  40    9800  4.2  yes   no  yes
# 91   210.0   26.0   1.7  136.0   3.8  16.1  52   12500  5.6   no   no   no
# 92   219.0   82.0   3.6  133.0   4.4  10.4  33    5600  3.6  yes  yes  yes
# 93   295.0   90.0   5.6  140.0   2.9   9.2  30    7000  3.2  yes  yes  yes
# 127  118.0  125.0   5.3  136.0   4.9  11.4  35   15200  4.3  yes  yes   no
# 128  224.0  166.0   5.6  133.0  47.0   8.1  23    5000  2.9  yes  yes   no
# 130  128.0  208.0   9.2  134.0   4.8   8.2  22   16300  2.7   no   no   no
# 133  118.0  125.0   5.3  136.0   4.9  12.0  37  \t8400  8.0  yes   no   no
# 144  105.0   53.0   2.3  136.0   5.2  11.1  33   10500  4.1   no   no   no
# 147  288.0   36.0   1.7  130.0   3.0   7.9  25   15200  3.0  yes   no   no
# 153  273.0  235.0  14.2  132.0   3.4   8.3  22   14600  2.9  yes  yes   no
# 157  122.0   42.0   1.7  136.0   4.7  12.6  39    7900  3.9  yes  yes   no
# 159  303.0   35.0   1.3  122.0   3.5  10.4  35   10900  4.3   no  yes   no
# 171  102.0   60.0   2.6  115.0   5.7   8.7  26   12800  3.1  yes   no   no
# 176  107.0   40.0   1.7  125.0   3.5   8.3  23   12400  3.9   no   no   no
# 181  117.0   52.0   2.2  136.0   3.8  10.0  30   19100  3.7   no   no   no
# 189  239.0   58.0   4.3  137.0   5.4   9.5  29    7500  3.4  yes  yes   no
# ..     ...    ...   ...    ...   ...   ...  ..     ...  ...  ...  ...  ...
# 368   82.0   42.0   0.7  146.0   5.0  14.9  45    9400  5.9   no   no   no
# 369  107.0   48.0   0.8  144.0   3.5  13.6  46   10300  4.8   no   no   no
# 370   83.0   42.0   1.2  139.0   3.7  16.2  50    9300  5.4   no   no   no
# 371   79.0   50.0   0.5  145.0   5.0  17.6  51    6500  5.0   no   no   no
# 372  109.0   26.0   0.9  150.0   4.9  15.0  52   10500  5.5   no   no   no
# 373  133.0   38.0   1.0  142.0   3.6  13.7  47    9200  4.9   no   no   no
# 374  111.0   44.0   1.2  146.0   3.6  16.3  40    8000  6.4   no   no   no
# 375   74.0   41.0   0.5  143.0   4.5  15.1  48    9700  5.6   no   no   no
# 376   88.0   16.0   1.1  147.0   3.5  16.4  53    9100  5.2   no   no   no
# 377   97.0   27.0   0.7  145.0   4.8  13.8  49    6400  4.8   no   no   no
# 379   78.0   45.0   0.6  138.0   3.5  16.1  50    5400  5.7   no   no   no
# 380  113.0   23.0   1.1  139.0   3.5  15.3  54    6500  4.9   no   no   no
# 382   75.0   22.0   0.8  137.0   5.0  16.8  51    6000  6.5   no   no   no
# 383  119.0   46.0   0.7  141.0   4.9  13.9  49    5100  5.0   no   no   no
# 384  132.0   18.0   1.1  150.0   4.7  15.4  42   11000  4.5   no   no   no
# 385  113.0   25.0   0.6  146.0   4.9  16.5  52    8000  5.1   no   no   no
# 386  100.0   47.0   0.5  142.0   3.5  16.4  43    5700  6.5   no   no   no
# 387   93.0   17.0   0.9  136.0   3.9  16.7  50    6200  5.2   no   no   no
# 388   94.0   15.0   1.2  144.0   3.7  15.5  46    9500  6.4   no   no   no
# 389  112.0   48.0   0.7  140.0   5.0  17.0  52    7200  5.8   no   no   no
# 390   99.0   25.0   0.8  135.0   3.7  15.0  52    6300  5.3   no   no   no
# 391   85.0   16.0   1.1  142.0   4.1  15.6  44    5800  6.3   no   no   no
# 392  133.0   48.0   1.2  147.0   4.3  14.8  46    6600  5.5   no   no   no
# 393  117.0   45.0   0.7  141.0   4.4  13.0  54    7400  5.4   no   no   no
# 394  137.0   46.0   0.8  139.0   5.0  14.1  45    9500  4.6   no   no   no
# 395  140.0   49.0   0.5  150.0   4.9  15.7  47    6700  4.9   no   no   no
# 396   75.0   31.0   1.2  141.0   3.5  16.5  54    7800  6.2   no   no   no
# 397  100.0   26.0   0.6  137.0   4.4  15.8  49    6600  5.4   no   no   no
# 398  114.0   50.0   1.0  135.0   4.9  14.2  51    7200  5.9   no   no   no
# 399  131.0   18.0   1.1  141.0   3.5  15.8  53    6800  6.1   no   no   no
#
#     appet   pe  ane classification
# 3    poor  yes  yes            ckd
# 9    poor   no  yes            ckd
# 11   poor  yes   no            ckd
# 14   poor  yes   no            ckd
# 20   poor  yes  yes            ckd
# 22   good   no  yes            ckd
# 27   good  yes   no            ckd
# 48   good  yes   no            ckd
# 58   good   no   no            ckd
# 71   good   no   no            ckd
# 74   good   no   no            ckd
# 76   good  yes   no            ckd
# 84   poor  yes  yes            ckd
# 90   good   no   no            ckd
# 91   good   no   no            ckd
# 92   good   no   no            ckd
# 93   poor   no   no            ckd
# 127  poor  yes   no            ckd
# 128  good   no  yes            ckd
# 130  poor  yes  yes            ckd
# 133  good   no   no            ckd
# 144  good   no   no            ckd
# 147  poor   no  yes            ckd
# 153  poor  yes  yes            ckd
# 157  good   no   no            ckd
# 159  poor   no   no            ckd
# 171  poor   no  yes            ckd
# 176  good   no  yes            ckd
# 181  good   no   no            ckd
# 189  poor  yes   no            ckd
# ..    ...  ...  ...            ...
# 368  good   no   no         notckd
# 369  good   no   no         notckd
# 370  good   no   no         notckd
# 371  good   no   no         notckd
# 372  good   no   no         notckd
# 373  good   no   no         notckd
# 374  good   no   no         notckd
# 375  good   no   no         notckd
# 376  good   no   no         notckd
# 377  good   no   no         notckd
# 379  good   no   no         notckd
# 380  good   no   no         notckd
# 382  good   no   no         notckd
# 383  good   no   no         notckd
# 384  good   no   no         notckd
# 385  good   no   no         notckd
# 386  good   no   no         notckd
# 387  good   no   no         notckd
# 388  good   no   no         notckd
# 389  good   no   no         notckd
# 390  good   no   no         notckd
# 391  good   no   no         notckd
# 392  good   no   no         notckd
# 393  good   no   no         notckd
# 394  good   no   no         notckd
# 395  good   no   no         notckd
# 396  good   no   no         notckd
# 397  good   no   no         notckd
# 398  good   no   no         notckd
# 399  good   no   no         notckd
#
# [158 rows x 26 columns]

# %%
df['pcc'].replace('notpresent',0,inplace=True)
df['pcc'].replace('present',1,inplace=True)

# %%
df['ba'].replace('notpresent',0,inplace=True)
df['ba'].replace('present',1,inplace=True)

# %%
#htn	dm	cad
df['htn'].replace('no',0,inplace=True)
df['htn'].replace('yes',1,inplace=True)

# %%
df['dm'].replace('no',0,inplace=True)
df['dm'].replace('yes',1,inplace=True)

# %%
df['cad'].replace('no',0,inplace=True)
df['cad'].replace('yes',1,inplace=True)

# %%
#pe	ane
df['pe'].replace('no',0,inplace=True)
df['ane'].replace('yes',1,inplace=True)

# %%
#appet
df['appet'].replace('poor',0,inplace=True)
df['appet'].replace('good',1,inplace=True)

# %%
df.head()
# Out:
#     id   age    bp     sg   al   su  rbc        pc         pcc  ba    bgr  \
# 3    3  48.0  70.0  1.005  4.0  0.0    1  abnormal     present   0  117.0
# 9    9  53.0  90.0  1.020  2.0  0.0    0  abnormal     present   0   70.0
# 11  11  63.0  70.0  1.010  3.0  0.0    0  abnormal     present   0  380.0
# 14  14  68.0  80.0  1.010  3.0  2.0    1  abnormal     present   1  157.0
# 20  20  61.0  80.0  1.015  2.0  0.0    0  abnormal  notpresent   0  173.0
#
#        bu   sc    sod  pot  hemo pcv     wc   rc  htn  dm  cad  appet   pe  \
# 3    56.0  3.8  111.0  2.5  11.2  32   6700  3.9    1   0    0      0  yes
# 9   107.0  7.2  114.0  3.7   9.5  29  12100  3.7    1   1    0      0    0
# 11   60.0  2.7  131.0  4.2  10.8  32   4500  3.8    1   1    0      0  yes
# 14   90.0  4.1  130.0  6.4   5.6  16  11000  2.6    1   1    1      0  yes
# 20  148.0  3.9  135.0  5.2   7.7  24   9200  3.2    1   1    1      0  yes
#
#    ane classification
# 3    1            ckd
# 9    1            ckd
# 11  no            ckd
# 14  no            ckd
# 20   1            ckd
